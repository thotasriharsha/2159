# %% [markdown]
# <a href="https://colab.research.google.com/github/thotasriharsha/2159/blob/main/LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![bfs.jpg](data:image/jpeg;base64,...)

# %%
from queue import Queue

graph = {0: [2,2,3],
         1: [0,2],
         2: [1, 3, 5],
         3: [0, 2, 4],
         4: [3, 5 , 7],
         5: [2, 4, 6, 7],
         6: [5, 7],
         7: []}
print(graph)


def bfs(graph, source):
  Q = Queue()
  visited_vertices = set()
  Q.put(source)
  visited_vertices.update({source})
  while not Q.empty():
    vertex = Q.get()
    print(vertex, end=" -->")
    for u in graph[vertex]:
      if u not in visited_vertices:
        Q.put(u)
        visited_vertices.update({u})

print("BFS traversal of graph with source 1 is:")
bfs(graph,1)
# Out:
# {0: [2, 2, 3], 1: [0, 2], 2: [1, 3, 5], 3: [0, 2, 4], 4: [3, 5, 7], 5: [2, 4, 6, 7], 6: [5, 7], 7: []}
# BFS traversal of graph with source 1 is:
# 1 -->0 -->2 -->3 -->5 -->4 -->6 -->7 -->

# %% [markdown]
# ![dfs.jpg](data:image/jpeg;base64,...)

# %%
from queue import Queue

graph = {'A':['G','D','B','C'],
         'B':['A','C'],
         'C':['D','A','B'],
         'D':['C','A','G','H','E'],
         'E':['F','H','D'],
         'F':['E','C'],
         'G':['A','D','H'],
         'H':['G','E','D']}

print("The adjanceny list representing the graph is: ")
print(graph)
def dfs(graph, source):
  Q = Queue()
  visited_vertices=set()
  Q.put(source)
  visited_vertices.update((source))
  while not Q.empty():
    vertex = Q.get()
    print(vertex, end="-->")
    for u in graph[vertex]:
         if u not in visited_vertices:
              Q.put(u)
              visited_vertices.update({u})
print("DFS transversal of graph with source 1 is:")
# Out:
# The adjanceny list representing the graph is:
# {'A': ['G', 'D', 'B', 'C'], 'B': ['A', 'C'], 'C': ['D', 'A', 'B'], 'D': ['C', 'A', 'G', 'H', 'E'], 'E': ['F', 'H', 'D'], 'F': ['E', 'C'], 'G': ['A', 'D', 'H'], 'H': ['G', 'E', 'D']}
# DFS transversal of graph with source 1 is:
